# %%
import numpy as np
import pandas as pd
import os
from eppy import modeleditor 
from eppy.modeleditor import IDF

# %%
building_path = r".\building"
weather_path = r".\weather"

# %%
site = "CHICAGO"
results = "RefBldgLargeOfficePost1980_v1.3_5.0_5A_USA_IL_CHICAGO-OHARE.csv"
idf = "RefBldgLargeOfficePost1980_v1.3_5.0_5A_USA_IL_CHICAGO-OHARE.idf"
data_path = os.path.join(building_path, site, results)
idf_path = os.path.join(building_path, site, idf)
df = pd.read_csv(data_path)
df.head()
# Out:
#           Date/Time  \
# 0   01/01  01:00:00
# 1   01/01  02:00:00
# 2   01/01  03:00:00
# 3   01/01  04:00:00
# 4   01/01  05:00:00
#
#    Environment:Site Outdoor Air Drybulb Temperature [C](Hourly)  \
# 0                                          -7.825000
# 1                                         -11.908333
# 2                                         -11.350000
# 3                                         -11.100000
# 4                                         -10.808333
#
#    Environment:Site Outdoor Air Humidity Ratio [kgWater/kgDryAir](Hourly)  \
# 0                                           0.001479
# 1                                           0.001001
# 2                                           0.001053
# 3                                           0.001077
# 4                                           0.001106
#
#    Environment:Site Outdoor Air Relative Humidity [%](Hourly)  \
# 0                                          72.583333
# ...

# %%
IDF.setiddname("C:\EnergyPlusV24-1-0\PreProcess\IDFVersionUpdater\V24-1-0-Energy+.idd")
idf = IDF(idf_path)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\Aoyu Zou\AppData\Local\Temp\ipykernel_12368\1726833541.py:1: SyntaxWarning: invalid escape sequence '\E'
#   IDF.setiddname("C:\EnergyPlusV24-1-0\PreProcess\IDFVersionUpdater\V24-1-0-Energy+.idd")

# %%
chillers = idf.idfobjects["Chiller:Electric:ReformulatedEIR"]
# Create an always-off schedule

for chiller in chillers:
    if chiller.Name == "CoolSys1 Chiller 1":
        chiller.Reference_Capacity = "AUTOSIZE"
    else:
        chiller.Reference_Capacity = 0.001
        chiller.Reference_Chilled_Water_Flow_Rate = 0.001

idf.save(r".\test\modified.idf")
